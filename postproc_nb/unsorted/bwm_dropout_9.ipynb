# %%
# %load_ext autoreload

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pickle

from enterprise import constants as const
from enterprise.signals import parameter
from enterprise.signals import selections
from enterprise.signals import signal_base
from enterprise.signals import white_signals
from enterprise.signals import gp_signals
from enterprise.signals import deterministic_signals
from enterprise.signals import utils

from utils import models
from utils import hypermod
from utils.sample_helpers import JumpProposal, get_parameter_groups

from utils import sample_utils as su

from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc
from acor import acor

# %matplotlib inline
# %autoreload 2

# %% [markdown]
# # Read in data

# %%
ephem = 'DE436'
datadir = '/home/pbaker/nanograv/data/'

# %%
# read in data pickles
filename = datadir + 'nano9_{}.pkl'.format(ephem)
with open(filename, "rb") as f:
    psrs = pickle.load(f)

filename = datadir + 'nano9_setpars.pkl'
with open(filename, "rb") as f:
    noise_dict = pickle.load(f)

# %%
#psr_use = models.which_psrs(psrs, slice_yr, 3)  # select pulsars
psr_9yr = [ # the NG 9yr pulsars
    'J1713+0747',
    'J1909-3744',
    'J1640+2224',
    'J1600-3053',
    'J2317+1439',
    'J1918-0642',
    'J1614-2230',
    'J1744-1134',
    'J0030+0451',
    'J2145-0750',
    'B1855+09',
    'J1853+1303',
    'J0613-0200',
    'J1455-3330',
    'J1741+1351',
    'J2010-1323',
    'J1024-0719',
    'J1012+5307',
]

psrs = [p for p in psrs if p.name in psr_9yr]

# %% [markdown]
# # setup models

# %% [markdown]
# ## custom BWM w/ k param

# %%
@signal_base.function
def bwm_delay(toas, pos, log10_h=-14.0, cos_gwtheta=0.0, gwphi=0.0,
              gwpol=0.0, t0=55000, psrk=1, antenna_pattern_fn=None):
    """
    Function that calculates the earth-term gravitational-wave
    burst-with-memory signal, as described in:
    Seto et al, van haasteren and Levin, phsirkov et al, Cordes and Jenet.
    This version uses the F+/Fx polarization modes, as verified with the
    Continuous Wave and Anisotropy papers.
    :param toas: Time-of-arrival measurements [s]
    :param pos: Unit vector from Earth to pulsar
    :param log10_h: log10 of GW strain
    :param cos_gwtheta: Cosine of GW polar angle
    :param gwphi: GW azimuthal polar angle [rad]
    :param gwpol: GW polarization angle
    :param t0: Burst central time [day]
    :param antenna_pattern_fn:
        User defined function that takes `pos`, `gwtheta`, `gwphi` as
        arguments and returns (fplus, fcross)
    :return: the waveform as induced timing residuals (seconds)
    """

    # convert
    h = 10**log10_h
    gwtheta = np.arccos(cos_gwtheta)
    t0 *= const.day

    # antenna patterns
    if antenna_pattern_fn is None:
        apc = utils.create_gw_antenna_pattern(pos, gwtheta, gwphi)
    else:
        apc = antenna_pattern_fn(pos, gwtheta, gwphi)

    # grab fplus, fcross
    fp, fc = apc[0], apc[1]

    # combined polarization
    pol = np.cos(2*gwpol)*fp + np.sin(2*gwpol)*fc

    # Define the heaviside function
    heaviside = lambda x: 0.5 * (np.sign(x) + 1)

    k = np.rint(psrk)
    
    # Return the time-series for the pulsar
    return k * pol * h * heaviside(toas-t0) * (toas-t0)

# %% [markdown]
# ## build PTA

# %%
outdir = '/home/pbaker/nanograv/bwm/dropout/'
# !mkdir -p $outdir

# %%
# find the maximum time span to set frequency sampling
tmin = np.min([p.toas.min() for p in psrs])
tmax = np.max([p.toas.max() for p in psrs])
Tspan = tmax - tmin
print("Tspan = {:f} sec ~ {:.2f} yr".format(Tspan, Tspan/const.yr))

# find clipped prior range for bwm_t0
clip = 0.05 * Tspan
t0min = (tmin + 2*clip)/const.day  # don't search in first 10%
t0max = (tmax - clip)/const.day  # don't search in last 5%
print("search for t0 in [{:.1f}, {:.1f}] MJD".format(t0min, t0max))
# Out:
# Tspan = 292290292.653352 sec ~ 9.26 yr
# search for t0 in [53554.4, 56430.0] MJD

# %%
anomaly = {
    'bwm_costheta':0.10,
    'bwm_log10_A':-12.77,
    'bwm_phi':1.15,
    'bwm_pol':2.81,
    'bwm_t0':55421.59,
}

# %%
# White Noise
selection = selections.Selection(selections.by_backend)

efac = parameter.Constant()
equad = parameter.Constant()
ecorr = parameter.Constant()

ef = white_signals.MeasurementNoise(efac=efac, selection=selection)
eq = white_signals.EquadNoise(log10_equad=equad, selection=selection)
ec = white_signals.EcorrKernelNoise(log10_ecorr=ecorr, selection=selection)

wn = ef + eq + ec


# Red Noise
rn_log10_A = parameter.Uniform(-20, -11)
rn_gamma = parameter.Uniform(0, 7)
rn_powlaw = utils.powerlaw(log10_A=rn_log10_A, gamma=rn_gamma)
rn = gp_signals.FourierBasisGP(rn_powlaw, components=30, Tspan=Tspan)


# BWM signal
name = 'bwm'
amp_name = '{}_log10_A'.format(name)
bwm_log10_A = parameter.Uniform(-18, -12)(amp_name)

pol_name = '{}_pol'.format(name)
pol = parameter.Constant(anomaly[pol_name])(pol_name)

t0_name = '{}_t0'.format(name)
t0 = parameter.Constant(anomaly[t0_name])(t0_name)

costh_name = '{}_costheta'.format(name)
phi_name = '{}_phi'.format(name)
costh = parameter.Constant(anomaly[costh_name])(costh_name)
phi = parameter.Constant(anomaly[phi_name])(phi_name)

k = parameter.Uniform(0,1) # not common, one per PSR
bwm_wf = bwm_delay(log10_h=bwm_log10_A, t0=t0,
                   cos_gwtheta=costh, gwphi=phi, gwpol=pol,
                   psrk=k)
bwm = deterministic_signals.Deterministic(bwm_wf, name=name)


# Timing Model
tm = gp_signals.TimingModel(use_svd=True)

# %%
mod = tm + wn + rn + bwm

pta = signal_base.PTA([mod(psr) for psr in psrs])
pta.set_default_params(noise_dict)
# Out:
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_efac to 1.13965
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_efac to 1.12121
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_efac to 1.14383
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_efac to 1.51117
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_log10_equad to -8.09925
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_log10_equad to -7.96027
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_log10_equad to -6.31998
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_log10_equad to -6.42638
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_log10_ecorr to -7.38511
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_log10_ecorr to -7.28084
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_log10_ecorr to -6.10018
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_log10_ecorr to -6.48309
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_efac to 1.13871
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_efac to 0.917359
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_efac to 1.12336
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_efac to 1.14101
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_log10_equad to -8.27762
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_log10_equad to -5.94568
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_log10_ecorr to -6.14458
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_log10_ecorr to -6.49356
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_log10_ecorr to -7.59813

# %%
summary = pta.summary()
print(summary)
# Out:
# Signal Name                              Signal Class                   no. Parameters
# ==========================================================================================
# B1855+09_linear_timing_model_svd         TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# B1855+09_efac                            MeasurementNoise               0
#
# params:
# B1855+09_430_ASP_efac:Constant=1.13965
# B1855+09_430_PUPPI_efac:Constant=1.12121
# B1855+09_L-wide_ASP_efac:Constant=1.14383
# B1855+09_L-wide_PUPPI_efac:Constant=1.51117
# __________________________________________________________________________________________
# B1855+09_equad                           EquadNoise                     0
#
# params:
# B1855+09_430_ASP_log10_equad:Constant=-8.09925
# B1855+09_430_PUPPI_log10_equad:Constant=-7.96027
# B1855+09_L-wide_ASP_log10_equad:Constant=-6.31998
# B1855+09_L-wide_PUPPI_log10_equad:Constant=-6.42638
# __________________________________________________________________________________________
# B1855+09_ecorr_sherman-morrison          EcorrKernelNoise               0
#
# params:
# B1855+09_430_ASP_log10_ecorr:Constant=-7.38511
# B1855+09_430_PUPPI_log10_ecorr:Constant=-7.28084
# B1855+09_L-wide_ASP_log10_ecorr:Constant=-6.10018
# B1855+09_L-wide_PUPPI_log10_ecorr:Constant=-6.48309
# __________________________________________________________________________________________
# B1855+09_red_noise                       FourierBasisGP                 2
#
# params:
# B1855+09_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# B1855+09_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1855+09_bwm                             Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# B1855+09_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J0030+0451_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0030+0451_efac                          MeasurementNoise               0
#
# params:
# J0030+0451_430_ASP_efac:Constant=1.13871
# J0030+0451_430_PUPPI_efac:Constant=0.917359
# J0030+0451_L-wide_ASP_efac:Constant=1.12336
# J0030+0451_L-wide_PUPPI_efac:Constant=1.14101
# __________________________________________________________________________________________
# J0030+0451_equad                         EquadNoise                     0
#
# params:
# J0030+0451_430_ASP_log10_equad:Constant=-8.27762
# J0030+0451_430_PUPPI_log10_equad:Constant=-5.94568
# J0030+0451_L-wide_ASP_log10_equad:Constant=-8.17663
# J0030+0451_L-wide_PUPPI_log10_equad:Constant=-6.67303
# __________________________________________________________________________________________
# J0030+0451_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J0030+0451_430_ASP_log10_ecorr:Constant=-7.6001
# J0030+0451_430_PUPPI_log10_ecorr:Constant=-7.11084
# J0030+0451_L-wide_ASP_log10_ecorr:Constant=-7.59912
# J0030+0451_L-wide_PUPPI_log10_ecorr:Constant=-7.64239
# __________________________________________________________________________________________
# J0030+0451_red_noise                     FourierBasisGP                 2
#
# params:
# J0030+0451_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0030+0451_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0030+0451_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J0030+0451_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J0613-0200_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0613-0200_efac                          MeasurementNoise               0
#
# params:
# J0613-0200_Rcvr1_2_GASP_efac:Constant=1.08413
# J0613-0200_Rcvr1_2_GUPPI_efac:Constant=1.08569
# J0613-0200_Rcvr_800_GASP_efac:Constant=1.09303
# J0613-0200_Rcvr_800_GUPPI_efac:Constant=1.19709
# __________________________________________________________________________________________
# J0613-0200_equad                         EquadNoise                     0
#
# params:
# J0613-0200_Rcvr1_2_GASP_log10_equad:Constant=-8.29172
# J0613-0200_Rcvr1_2_GUPPI_log10_equad:Constant=-8.39354
# J0613-0200_Rcvr_800_GASP_log10_equad:Constant=-8.34563
# J0613-0200_Rcvr_800_GUPPI_log10_equad:Constant=-6.52894
# __________________________________________________________________________________________
# J0613-0200_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J0613-0200_Rcvr1_2_GASP_log10_ecorr:Constant=-7.51539
# J0613-0200_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.78395
# J0613-0200_Rcvr_800_GASP_log10_ecorr:Constant=-7.72404
# J0613-0200_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.53941
# __________________________________________________________________________________________
# J0613-0200_red_noise                     FourierBasisGP                 2
#
# params:
# J0613-0200_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0613-0200_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0613-0200_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J0613-0200_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1012+5307_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1012+5307_efac                          MeasurementNoise               0
#
# params:
# J1012+5307_Rcvr1_2_GASP_efac:Constant=1.05234
# J1012+5307_Rcvr1_2_GUPPI_efac:Constant=1.08498
# J1012+5307_Rcvr_800_GASP_efac:Constant=1.11456
# J1012+5307_Rcvr_800_GUPPI_efac:Constant=1.17272
# __________________________________________________________________________________________
# J1012+5307_equad                         EquadNoise                     0
#
# params:
# J1012+5307_Rcvr1_2_GASP_log10_equad:Constant=-8.04958
# J1012+5307_Rcvr1_2_GUPPI_log10_equad:Constant=-6.42345
# J1012+5307_Rcvr_800_GASP_log10_equad:Constant=-7.92351
# J1012+5307_Rcvr_800_GUPPI_log10_equad:Constant=-6.31253
# __________________________________________________________________________________________
# J1012+5307_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1012+5307_Rcvr1_2_GASP_log10_ecorr:Constant=-7.27863
# J1012+5307_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.68714
# J1012+5307_Rcvr_800_GASP_log10_ecorr:Constant=-7.63389
# J1012+5307_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.75432
# __________________________________________________________________________________________
# J1012+5307_red_noise                     FourierBasisGP                 2
#
# params:
# J1012+5307_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1012+5307_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1012+5307_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1012+5307_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1024-0719_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1024-0719_efac                          MeasurementNoise               0
#
# params:
# J1024-0719_Rcvr1_2_GASP_efac:Constant=0.923661
# J1024-0719_Rcvr1_2_GUPPI_efac:Constant=1.14266
# J1024-0719_Rcvr_800_GASP_efac:Constant=1.01755
# J1024-0719_Rcvr_800_GUPPI_efac:Constant=1.19071
# __________________________________________________________________________________________
# J1024-0719_equad                         EquadNoise                     0
#
# params:
# J1024-0719_Rcvr1_2_GASP_log10_equad:Constant=-7.54914
# J1024-0719_Rcvr1_2_GUPPI_log10_equad:Constant=-8.49668
# J1024-0719_Rcvr_800_GASP_log10_equad:Constant=-7.94691
# J1024-0719_Rcvr_800_GUPPI_log10_equad:Constant=-8.542
# __________________________________________________________________________________________
# J1024-0719_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1024-0719_Rcvr1_2_GASP_log10_ecorr:Constant=-7.08522
# J1024-0719_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.00321
# J1024-0719_Rcvr_800_GASP_log10_ecorr:Constant=-6.96383
# J1024-0719_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.29206
# __________________________________________________________________________________________
# J1024-0719_red_noise                     FourierBasisGP                 2
#
# params:
# J1024-0719_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1024-0719_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1024-0719_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1024-0719_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1455-3330_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1455-3330_efac                          MeasurementNoise               0
#
# params:
# J1455-3330_Rcvr1_2_GASP_efac:Constant=1.12806
# J1455-3330_Rcvr1_2_GUPPI_efac:Constant=1.32475
# J1455-3330_Rcvr_800_GASP_efac:Constant=1.49365
# J1455-3330_Rcvr_800_GUPPI_efac:Constant=1.35131
# __________________________________________________________________________________________
# J1455-3330_equad                         EquadNoise                     0
#
# params:
# J1455-3330_Rcvr1_2_GASP_log10_equad:Constant=-8.04522
# J1455-3330_Rcvr1_2_GUPPI_log10_equad:Constant=-8.37397
# J1455-3330_Rcvr_800_GASP_log10_equad:Constant=-8.08877
# J1455-3330_Rcvr_800_GUPPI_log10_equad:Constant=-8.40589
# __________________________________________________________________________________________
# J1455-3330_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1455-3330_Rcvr1_2_GASP_log10_ecorr:Constant=-6.06065
# J1455-3330_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.56026
# J1455-3330_Rcvr_800_GASP_log10_ecorr:Constant=-7.24673
# J1455-3330_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.35803
# __________________________________________________________________________________________
# J1455-3330_red_noise                     FourierBasisGP                 2
#
# params:
# J1455-3330_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1455-3330_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1455-3330_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1455-3330_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1600-3053_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1600-3053_efac                          MeasurementNoise               0
#
# params:
# J1600-3053_Rcvr1_2_GASP_efac:Constant=1.13991
# J1600-3053_Rcvr1_2_GUPPI_efac:Constant=1.05637
# J1600-3053_Rcvr_800_GASP_efac:Constant=1.18543
# J1600-3053_Rcvr_800_GUPPI_efac:Constant=1.12855
# __________________________________________________________________________________________
# J1600-3053_equad                         EquadNoise                     0
#
# params:
# J1600-3053_Rcvr1_2_GASP_log10_equad:Constant=-7.77574
# J1600-3053_Rcvr1_2_GUPPI_log10_equad:Constant=-8.31385
# J1600-3053_Rcvr_800_GASP_log10_equad:Constant=-8.07856
# J1600-3053_Rcvr_800_GUPPI_log10_equad:Constant=-8.09682
# __________________________________________________________________________________________
# J1600-3053_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1600-3053_Rcvr1_2_GASP_log10_ecorr:Constant=-7.41423
# J1600-3053_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.78034
# J1600-3053_Rcvr_800_GASP_log10_ecorr:Constant=-7.42253
# J1600-3053_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.3244
# __________________________________________________________________________________________
# J1600-3053_red_noise                     FourierBasisGP                 2
#
# params:
# J1600-3053_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1600-3053_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1600-3053_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1600-3053_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1614-2230_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1614-2230_efac                          MeasurementNoise               0
#
# params:
# J1614-2230_Rcvr1_2_GASP_efac:Constant=1.15849
# J1614-2230_Rcvr1_2_GUPPI_efac:Constant=1.06146
# J1614-2230_Rcvr_800_GASP_efac:Constant=0.915636
# J1614-2230_Rcvr_800_GUPPI_efac:Constant=1.01366
# __________________________________________________________________________________________
# J1614-2230_equad                         EquadNoise                     0
#
# params:
# J1614-2230_Rcvr1_2_GASP_log10_equad:Constant=-8.02865
# J1614-2230_Rcvr1_2_GUPPI_log10_equad:Constant=-8.53141
# J1614-2230_Rcvr_800_GASP_log10_equad:Constant=-8.01389
# J1614-2230_Rcvr_800_GUPPI_log10_equad:Constant=-8.34908
# __________________________________________________________________________________________
# J1614-2230_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1614-2230_Rcvr1_2_GASP_log10_ecorr:Constant=-7.13589
# J1614-2230_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.63
# J1614-2230_Rcvr_800_GASP_log10_ecorr:Constant=-7.13582
# J1614-2230_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.78123
# __________________________________________________________________________________________
# J1614-2230_red_noise                     FourierBasisGP                 2
#
# params:
# J1614-2230_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1614-2230_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1614-2230_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1614-2230_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1640+2224_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1640+2224_efac                          MeasurementNoise               0
#
# params:
# J1640+2224_430_ASP_efac:Constant=1.18797
# J1640+2224_430_PUPPI_efac:Constant=1.13544
# J1640+2224_L-wide_ASP_efac:Constant=1.07335
# J1640+2224_L-wide_PUPPI_efac:Constant=1.25304
# __________________________________________________________________________________________
# J1640+2224_equad                         EquadNoise                     0
#
# params:
# J1640+2224_430_ASP_log10_equad:Constant=-6.26644
# J1640+2224_430_PUPPI_log10_equad:Constant=-7.48076
# J1640+2224_L-wide_ASP_log10_equad:Constant=-8.40253
# J1640+2224_L-wide_PUPPI_log10_equad:Constant=-8.61952
# __________________________________________________________________________________________
# J1640+2224_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1640+2224_430_ASP_log10_ecorr:Constant=-7.75415
# J1640+2224_430_PUPPI_log10_ecorr:Constant=-7.0865
# J1640+2224_L-wide_ASP_log10_ecorr:Constant=-6.38835
# J1640+2224_L-wide_PUPPI_log10_ecorr:Constant=-7.67906
# __________________________________________________________________________________________
# J1640+2224_red_noise                     FourierBasisGP                 2
#
# params:
# J1640+2224_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1640+2224_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1640+2224_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1640+2224_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1713+0747_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1713+0747_efac                          MeasurementNoise               0
#
# params:
# J1713+0747_L-wide_ASP_efac:Constant=1.02902
# J1713+0747_L-wide_PUPPI_efac:Constant=1.1659
# J1713+0747_Rcvr1_2_GASP_efac:Constant=1.0879
# J1713+0747_Rcvr1_2_GUPPI_efac:Constant=1.19878
# J1713+0747_Rcvr_800_GASP_efac:Constant=1.19524
# J1713+0747_Rcvr_800_GUPPI_efac:Constant=1.06403
# J1713+0747_S-wide_ASP_efac:Constant=1.12282
# J1713+0747_S-wide_PUPPI_efac:Constant=1.08004
# __________________________________________________________________________________________
# J1713+0747_equad                         EquadNoise                     0
#
# params:
# J1713+0747_L-wide_ASP_log10_equad:Constant=-7.59213
# J1713+0747_L-wide_PUPPI_log10_equad:Constant=-8.90685
# J1713+0747_Rcvr1_2_GASP_log10_equad:Constant=-8.17586
# J1713+0747_Rcvr1_2_GUPPI_log10_equad:Constant=-8.29277
# J1713+0747_Rcvr_800_GASP_log10_equad:Constant=-8.365
# J1713+0747_Rcvr_800_GUPPI_log10_equad:Constant=-8.30246
# J1713+0747_S-wide_ASP_log10_equad:Constant=-8.7862
# J1713+0747_S-wide_PUPPI_log10_equad:Constant=-7.29251
# __________________________________________________________________________________________
# J1713+0747_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1713+0747_L-wide_ASP_log10_ecorr:Constant=-6.96775
# J1713+0747_L-wide_PUPPI_log10_ecorr:Constant=-7.00729
# J1713+0747_Rcvr1_2_GASP_log10_ecorr:Constant=-7.21635
# J1713+0747_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.23259
# J1713+0747_Rcvr_800_GASP_log10_ecorr:Constant=-7.76923
# J1713+0747_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.70639
# J1713+0747_S-wide_ASP_log10_ecorr:Constant=-6.95628
# J1713+0747_S-wide_PUPPI_log10_ecorr:Constant=-6.94551
# __________________________________________________________________________________________
# J1713+0747_red_noise                     FourierBasisGP                 2
#
# params:
# J1713+0747_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1713+0747_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1713+0747_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1713+0747_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1741+1351_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1741+1351_efac                          MeasurementNoise               0
#
# params:
# J1741+1351_430_ASP_efac:Constant=0.92739
# J1741+1351_430_PUPPI_efac:Constant=1.08265
# J1741+1351_L-wide_ASP_efac:Constant=1.03545
# J1741+1351_L-wide_PUPPI_efac:Constant=1.05026
# __________________________________________________________________________________________
# J1741+1351_equad                         EquadNoise                     0
#
# params:
# J1741+1351_430_ASP_log10_equad:Constant=-7.81532
# J1741+1351_430_PUPPI_log10_equad:Constant=-7.8145
# J1741+1351_L-wide_ASP_log10_equad:Constant=-8.31889
# J1741+1351_L-wide_PUPPI_log10_equad:Constant=-8.06543
# __________________________________________________________________________________________
# J1741+1351_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1741+1351_430_ASP_log10_ecorr:Constant=-5.26368
# J1741+1351_430_PUPPI_log10_ecorr:Constant=-7.35363
# J1741+1351_L-wide_ASP_log10_ecorr:Constant=-7.15877
# J1741+1351_L-wide_PUPPI_log10_ecorr:Constant=-7.31138
# __________________________________________________________________________________________
# J1741+1351_red_noise                     FourierBasisGP                 2
#
# params:
# J1741+1351_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1741+1351_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1741+1351_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1741+1351_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1744-1134_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1744-1134_efac                          MeasurementNoise               0
#
# params:
# J1744-1134_Rcvr1_2_GASP_efac:Constant=1.02696
# J1744-1134_Rcvr1_2_GUPPI_efac:Constant=1.21601
# J1744-1134_Rcvr_800_GASP_efac:Constant=1.16982
# J1744-1134_Rcvr_800_GUPPI_efac:Constant=1.04852
# __________________________________________________________________________________________
# J1744-1134_equad                         EquadNoise                     0
#
# params:
# J1744-1134_Rcvr1_2_GASP_log10_equad:Constant=-6.83644
# J1744-1134_Rcvr1_2_GUPPI_log10_equad:Constant=-6.73425
# J1744-1134_Rcvr_800_GASP_log10_equad:Constant=-6.47133
# J1744-1134_Rcvr_800_GUPPI_log10_equad:Constant=-6.5577
# __________________________________________________________________________________________
# J1744-1134_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1744-1134_Rcvr1_2_GASP_log10_ecorr:Constant=-6.3269
# J1744-1134_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.45387
# J1744-1134_Rcvr_800_GASP_log10_ecorr:Constant=-6.84423
# J1744-1134_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.57852
# __________________________________________________________________________________________
# J1744-1134_red_noise                     FourierBasisGP                 2
#
# params:
# J1744-1134_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1744-1134_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1744-1134_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1744-1134_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1853+1303_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1853+1303_efac                          MeasurementNoise               0
#
# params:
# J1853+1303_430_ASP_efac:Constant=1.10259
# J1853+1303_430_PUPPI_efac:Constant=1.07243
# J1853+1303_L-wide_ASP_efac:Constant=1.14229
# J1853+1303_L-wide_PUPPI_efac:Constant=1.14701
# __________________________________________________________________________________________
# J1853+1303_equad                         EquadNoise                     0
#
# params:
# J1853+1303_430_ASP_log10_equad:Constant=-7.82376
# J1853+1303_430_PUPPI_log10_equad:Constant=-8.01381
# J1853+1303_L-wide_ASP_log10_equad:Constant=-8.3849
# J1853+1303_L-wide_PUPPI_log10_equad:Constant=-8.44421
# __________________________________________________________________________________________
# J1853+1303_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1853+1303_430_ASP_log10_ecorr:Constant=-6.74256
# J1853+1303_430_PUPPI_log10_ecorr:Constant=-6.96278
# J1853+1303_L-wide_ASP_log10_ecorr:Constant=-7.48808
# J1853+1303_L-wide_PUPPI_log10_ecorr:Constant=-7.55986
# __________________________________________________________________________________________
# J1853+1303_red_noise                     FourierBasisGP                 2
#
# params:
# J1853+1303_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1853+1303_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1853+1303_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1853+1303_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1909-3744_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1909-3744_efac                          MeasurementNoise               0
#
# params:
# J1909-3744_Rcvr1_2_GASP_efac:Constant=0.986438
# J1909-3744_Rcvr1_2_GUPPI_efac:Constant=1.03462
# J1909-3744_Rcvr_800_GASP_efac:Constant=0.985523
# J1909-3744_Rcvr_800_GUPPI_efac:Constant=1.05208
# __________________________________________________________________________________________
# J1909-3744_equad                         EquadNoise                     0
#
# params:
# J1909-3744_Rcvr1_2_GASP_log10_equad:Constant=-7.97229
# J1909-3744_Rcvr1_2_GUPPI_log10_equad:Constant=-8.31285
# J1909-3744_Rcvr_800_GASP_log10_equad:Constant=-6.6358
# J1909-3744_Rcvr_800_GUPPI_log10_equad:Constant=-7.43842
# __________________________________________________________________________________________
# J1909-3744_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1909-3744_Rcvr1_2_GASP_log10_ecorr:Constant=-8.00662
# J1909-3744_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.13828
# J1909-3744_Rcvr_800_GASP_log10_ecorr:Constant=-7.86032
# J1909-3744_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.14764
# __________________________________________________________________________________________
# J1909-3744_red_noise                     FourierBasisGP                 2
#
# params:
# J1909-3744_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1909-3744_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1909-3744_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1909-3744_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J1918-0642_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1918-0642_efac                          MeasurementNoise               0
#
# params:
# J1918-0642_Rcvr1_2_GASP_efac:Constant=1.03139
# J1918-0642_Rcvr1_2_GUPPI_efac:Constant=1.09892
# J1918-0642_Rcvr_800_GASP_efac:Constant=1.05461
# J1918-0642_Rcvr_800_GUPPI_efac:Constant=1.09148
# __________________________________________________________________________________________
# J1918-0642_equad                         EquadNoise                     0
#
# params:
# J1918-0642_Rcvr1_2_GASP_log10_equad:Constant=-8.39359
# J1918-0642_Rcvr1_2_GUPPI_log10_equad:Constant=-8.20206
# J1918-0642_Rcvr_800_GASP_log10_equad:Constant=-7.9677
# J1918-0642_Rcvr_800_GUPPI_log10_equad:Constant=-8.4117
# __________________________________________________________________________________________
# J1918-0642_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J1918-0642_Rcvr1_2_GASP_log10_ecorr:Constant=-7.3475
# J1918-0642_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.37082
# J1918-0642_Rcvr_800_GASP_log10_ecorr:Constant=-7.55392
# J1918-0642_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.18419
# __________________________________________________________________________________________
# J1918-0642_red_noise                     FourierBasisGP                 2
#
# params:
# J1918-0642_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1918-0642_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1918-0642_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J1918-0642_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J2010-1323_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2010-1323_efac                          MeasurementNoise               0
#
# params:
# J2010-1323_Rcvr1_2_GASP_efac:Constant=0.967206
# J2010-1323_Rcvr1_2_GUPPI_efac:Constant=1.2128
# J2010-1323_Rcvr_800_GASP_efac:Constant=1.15777
# J2010-1323_Rcvr_800_GUPPI_efac:Constant=1.07888
# __________________________________________________________________________________________
# J2010-1323_equad                         EquadNoise                     0
#
# params:
# J2010-1323_Rcvr1_2_GASP_log10_equad:Constant=-7.69017
# J2010-1323_Rcvr1_2_GUPPI_log10_equad:Constant=-8.45324
# J2010-1323_Rcvr_800_GASP_log10_equad:Constant=-7.92738
# J2010-1323_Rcvr_800_GUPPI_log10_equad:Constant=-8.38299
# __________________________________________________________________________________________
# J2010-1323_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J2010-1323_Rcvr1_2_GASP_log10_ecorr:Constant=-7.1519
# J2010-1323_Rcvr1_2_GUPPI_log10_ecorr:Constant=-7.64287
# J2010-1323_Rcvr_800_GASP_log10_ecorr:Constant=-7.2034
# J2010-1323_Rcvr_800_GUPPI_log10_ecorr:Constant=-7.63276
# __________________________________________________________________________________________
# J2010-1323_red_noise                     FourierBasisGP                 2
#
# params:
# J2010-1323_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2010-1323_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2010-1323_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J2010-1323_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J2145-0750_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2145-0750_efac                          MeasurementNoise               0
#
# params:
# J2145-0750_Rcvr1_2_GASP_efac:Constant=1.00043
# J2145-0750_Rcvr1_2_GUPPI_efac:Constant=1.09892
# J2145-0750_Rcvr_800_GASP_efac:Constant=1.50673
# J2145-0750_Rcvr_800_GUPPI_efac:Constant=1.12959
# __________________________________________________________________________________________
# J2145-0750_equad                         EquadNoise                     0
#
# params:
# J2145-0750_Rcvr1_2_GASP_log10_equad:Constant=-5.70683
# J2145-0750_Rcvr1_2_GUPPI_log10_equad:Constant=-6.28759
# J2145-0750_Rcvr_800_GASP_log10_equad:Constant=-7.46919
# J2145-0750_Rcvr_800_GUPPI_log10_equad:Constant=-6.32362
# __________________________________________________________________________________________
# J2145-0750_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J2145-0750_Rcvr1_2_GASP_log10_ecorr:Constant=-6.72819
# J2145-0750_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.32176
# J2145-0750_Rcvr_800_GASP_log10_ecorr:Constant=-6.24509
# J2145-0750_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.57986
# __________________________________________________________________________________________
# J2145-0750_red_noise                     FourierBasisGP                 2
#
# params:
# J2145-0750_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2145-0750_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2145-0750_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J2145-0750_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# J2317+1439_linear_timing_model_svd       TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2317+1439_efac                          MeasurementNoise               0
#
# params:
# J2317+1439_327_ASP_efac:Constant=1.05869
# J2317+1439_327_PUPPI_efac:Constant=1.14332
# J2317+1439_430_ASP_efac:Constant=1.12607
# J2317+1439_430_PUPPI_efac:Constant=1.04287
# J2317+1439_L-wide_PUPPI_efac:Constant=0.954996
# __________________________________________________________________________________________
# J2317+1439_equad                         EquadNoise                     0
#
# params:
# J2317+1439_327_ASP_log10_equad:Constant=-6.41929
# J2317+1439_327_PUPPI_log10_equad:Constant=-6.39705
# J2317+1439_430_ASP_log10_equad:Constant=-6.92682
# J2317+1439_430_PUPPI_log10_equad:Constant=-6.4171
# J2317+1439_L-wide_PUPPI_log10_equad:Constant=-6.56296
# __________________________________________________________________________________________
# J2317+1439_ecorr_sherman-morrison        EcorrKernelNoise               0
#
# params:
# J2317+1439_327_ASP_log10_ecorr:Constant=-7.59726
# J2317+1439_327_PUPPI_log10_ecorr:Constant=-7.27493
# J2317+1439_430_ASP_log10_ecorr:Constant=-6.14458
# J2317+1439_430_PUPPI_log10_ecorr:Constant=-6.49356
# J2317+1439_L-wide_PUPPI_log10_ecorr:Constant=-7.59813
# __________________________________________________________________________________________
# J2317+1439_red_noise                     FourierBasisGP                 2
#
# params:
# J2317+1439_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2317+1439_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2317+1439_bwm                           Deterministic                  2
#
# params:
# bwm_log10_A:Uniform(pmin=-18, pmax=-12)
# bwm_t0:Constant=55421.59
# bwm_costheta:Constant=0.1
# bwm_phi:Constant=1.15
# bwm_pol:Constant=2.81
# J2317+1439_bwm_psrk:Uniform(pmin=0, pmax=1)
# __________________________________________________________________________________________
# ==========================================================================================
# Total params: 358
# Varying params: 55
# Common params: 18
# Fixed params: 303
# Number of pulsars: 18

# %% [markdown]
# # Sample

# %% [markdown]
# ## initial point and covariance matrix

# %%
x0 = np.hstack([noise_dict[p.name] if p.name in noise_dict.keys()
                else p.sample() for p in pta.params])  # initial point
ndim = len(x0)

# initial jump covariance matrix
# set initial cov stdev to (starting order of magnitude)/10
stdev = np.array([10**np.floor(np.log10(abs(x)))/10 for x in x0])
cov = np.diag(stdev**2)

# %% [markdown]
# ## sampling groups

# %%
# generate custom sampling groups
groups = [list(range(ndim))]  # all params

# pulsar noise groups (RN)
for psr in psrs:
    this_group = [pta.param_names.index(par)
                  for par in pta.param_names if psr.name in par]
    groups.append(this_group)

# all k params
this_group = []
for par in pta.param_names:
    if '_psrk' in par:
        this_group.append(pta.param_names.index(par))
groups.append(this_group)

# bwm params
this_group = [pta.param_names.index('bwm_log10_A')]
for ii in range(2):
    groups.append(this_group)
    
this_group = [pta.param_names.index(par)
              for par in pta.param_names if 'bwm_' in par]
groups.append(this_group)

# %% [markdown]
# ## initialize sampler object

# %%
sampler = ptmcmc(ndim, pta.get_lnlikelihood, pta.get_lnprior, cov, groups=groups,
                 outDir=outdir, resume=True)

# %%
sumfile = os.path.join(outdir, 'summary.txt')
with open(sumfile, 'w') as f:
    f.write(pta.summary())

outfile = os.path.join(outdir, 'params.txt')
with open(outfile, 'w') as f:
    for pname in pta.param_names:
        f.write(pname+'\n')

# %%
# additional proposals
full_prior = su.build_prior_draw(pta, pta.param_names, name='full_prior')
sampler.addProposalToCycle(full_prior, 5)

# RN empirical
#from utils.sample_utils import EmpiricalDistribution2D
#with open("/home/pbaker/nanograv/data/nano11_RNdistr.pkl", "rb") as f:
#    distr = pickle.load(f)
#Non4 = len(distr) // 4
#RN_emp = su.EmpDistrDraw(distr, pta.param_names, Nmax=Non4, name='RN_empirical')
#sampler.addProposalToCycle(RN_emp, 10)

# %% [markdown]
# ## sample it!

# %%
thin = 50
Nsamp = 100000 * 50
sampler.sample(x0, Nsamp,
               SCAMweight=30, AMweight=20, DEweight=50,
               burn=int(5e4), thin=thin)
# Out:
# Resuming run from chain file /home/pbaker/nanograv/bwm/dropout//chain_1.txt
# /home/pbaker/.local/opt/miniconda/envs/enterprise/lib/python3.6/site-packages/enterprise/signals/parameter.py:66: RuntimeWarning: divide by zero encountered in log
#   logpdf = np.log(self.prior(value, **kwargs))
# Finished 1.00 percent in 3540.528870 s Acceptance rate = 0.484182Adding DE jump with weight 50
# Finished 1.60 percent in 6396.584062 s Acceptance rate = 0.470939
